# %% [markdown]
# 6. Calculate the yield of the areas N-9.1, N-9.2, N-9.3 without external effects. Use the long-term corrected ERA5 data as
# input.

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import foxes
import foxes.variables as FV

# Data Paths
lidar_path = 'data/measurements/'
era5_path = 'data/reanalysis/'
turbines_existing_path = 'data/turbine-info/coordinates/existing/'
turbines_planned_future_path = 'data/turbine-info/coordinates/planned_future/'
turbines_planned_in_operation_before_2030_path = 'data/turbine-info/coordinates/planned_in_operation_before_2030/'
turbines_planned_netherlands_path = 'data/turbine-info/coordinates/planned_netherlands/'
turbines_area_of_interest_path = 'data/turbine-info/coordinates/area_of_interest/'
shapefiles_DEU_path = 'data/shapefiles/DEU/*'
shapefiles_DNK_path = 'data/shapefiles/DNK/*'
shapefiles_NLD_path = 'data/shapefiles/NLD/*'
turbine_power_curves_path = 'data/turbine-info/power_curves/'

# Function to read and extract data from csv files
def read_csv(path):
    data = pd.read_csv(path)
    return data

# %%
## get timeseries-data (here ERA5 as example)
from ERA5 import load_data,calculate_wind_speed,calculate_wind_direction,calculate_averages,check_data_gaps

Era5_path = 'data/reanalysis'  
start_year = 2000
end_year = 2001
    
Era5_data = load_data(Era5_path, start_year, end_year)
Era5_data = calculate_wind_speed(Era5_data)
Era5_data = calculate_wind_direction(Era5_data)

data = Era5_data
data.columns
# Out:
# Data Availability is 99.97%
# Missing time periods are:
# DatetimeIndex(['2023-02-26 00:00:00', '2023-02-26 01:00:00',
#                '2023-02-26 02:00:00', '2023-02-26 03:00:00',
#                '2023-02-26 04:00:00', '2023-02-26 05:00:00',
#                '2023-02-26 06:00:00', '2023-02-26 07:00:00',
#                '2023-02-26 08:00:00', '2023-02-26 09:00:00',
#                '2023-02-26 10:00:00', '2023-02-26 11:00:00',
#                '2023-02-26 12:00:00', '2023-02-26 13:00:00',
#                '2023-02-26 14:00:00', '2023-02-26 15:00:00',
#                '2023-02-26 16:00:00', '2023-02-26 17:00:00',
#                '2023-02-26 18:00:00', '2023-02-26 19:00:00',
#                '2023-02-26 20:00:00', '2023-02-26 21:00:00',
#                '2023-02-26 22:00:00', '2023-02-26 23:00:00',
#                '2023-02-27 00:00:00', '2023-02-27 01:00:00',
#                '2023-02-27 02:00:00', '2023-02-27 03:00:00',
#                '2023-02-27 04:00:00', '2023-02-27 05:00:00',
#                '2023-02-27 06:00:00', '2023-02-27 07:00:00',
#                '2023-02-27 08:00:00', '2023-02-27 09:00:00',
#                '2023-02-27 10:00:00', '2023-02-27 11:00:00',
#                '2023-02-27 12:00:00', '2023-02-27 13:00:00',
#                '2023-02-27 14:00:00', '2023-02-27 15:00:00',
#                '2023-02-27 16:00:00', '2023-02-27 17:00:00',
#                '2023-02-27 18:00:00', '2023-02-27 19:00:00',
#                '2023-02-27 20:00:00', '2023-02-27 21:00:00',
#                '2023-02-27 22:00:00', '2023-02-27 23:00:00',
#                '2023-02-28 00:00:00', '2023-02-28 01:00:00',
#                '2023-02-28 02:00:00', '2023-02-28 03:00:00',
#                '2023-02-28 04:00:00', '2023-02-28 05:00:00',
#                '2023-02-28 06:00:00', '2023-02-28 07:00:00',
#                '2023-02-28 08:00:00', '2023-02-28 09:00:00',
#                '2023-02-28 10:00:00', '2023-02-28 11:00:00',
#                '2023-02-28 12:00:00', '2023-02-28 13:00:00',
#                '2023-02-28 14:00:00', '2023-02-28 15:00:00',
#                '2023-02-28 16:00:00', '2023-02-28 17:00:00',
#                '2023-02-28 18:00:00', '2023-02-28 19:00:00',
#                '2023-02-28 20:00:00', '2023-02-28 21:00:00',
#                '2023-02-28 22:00:00', '2023-02-28 23:00:00'],
#               dtype='datetime64[ns]', freq='h')
# c:\Advanced Programming\Project\StudentProject-Yield-Predictions-Offshore\ERA5.py:62: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   full_time_range = pd.date_range(start=Era5_data.index.min(), end=Era5_data.index.max(), freq='H')
# Index(['Time [UTC]', 'u100', 'v100', 'u10', 'v10', 'WS100', 'WS10', 'WD100',
#        'WD10'],
#       dtype='object')

# %% [markdown]
# ## Task6

# %%
## Running Power calculation for each Area in a function

# import the custome function
from Foxes_Farm_Power import Foxes_Farm_Power
# Foxes_Farm_Power(Farm_Layout,States,Parameters)
    # Farm   : pd.datafram containing Layout of Turbines
    # States : Wind conditions
    # Parameters: dict
        # TType         : Turbine-Type           # "NREL5MW" , "IEA15MW"
        # rotor_model   :
        # wake_models   :
        # partial_wakes :

###-------------------------------------get Turbine Layouts----------------------------------###
# create 3 Dataframes for Turbine Layouts
current_path =  turbines_area_of_interest_path
turb_files = os.listdir(current_path)
Turb_dfs = [(read_csv(current_path + file),file) for file in turb_files] #read files in path to dataframe and put's those in list, also pass filename

###----------------------------------------Add States-----------------------------------------###
# define States as Foxes object and have a look at the wind rose.
# Wind and other atmospheric inflow conditions are called `States`
States = foxes.input.states.Timeseries(                      # StatesTable for panda df or pd readable file (single height)
    data_source = data ,                                         # the data
    output_vars = [FV.WS, FV.WD, FV.TI, FV.RHO],
    var2col =     {FV.WS: "WS100", FV.WD: "WD100", FV.TI: "ti"}, # Mapping from variable names to data column names
    fixed_vars =  {FV.RHO: 1.225, FV.TI: 0.05},                  # TI = Turbulanze 
    )

# Plot windrose
o = foxes.output.StatesRosePlotOutput(States, point=[0., 0., 100.])
fig = o.get_figure(16, FV.AMB_WS, [0, 3.5, 6, 10, 15, 20], figsize=(6, 6))
plt.show()

###--------------------------------------Important Parameters---------------------------------------###
Parameters = dict(                              # passed to the foxes.algorithms.Downwind()
    TType         = "IEA15MW",                  #"NREL5MW","IEA15MW"
    rotor_model   = "centre",
    wake_models   = ["Bastankhah2014_linear"],
    partial_wakes = None,
    )

###--------------------------------------compute farm results--------------------------------------###
Farm_Results = []
for Farm in Turb_dfs:
    Farm_Results.append(Foxes_Farm_Power(Farm,States,Parameters))
    
# algo.all_models(with_states=True) ##return all models used in our algo
# Out:
# Turbine 0, T0: kTI_02, IEA15MW
# Turbine 1, T1: kTI_02, IEA15MW
# Turbine 2, T2: kTI_02, IEA15MW
# Turbine 3, T3: kTI_02, IEA15MW
# Turbine 4, T4: kTI_02, IEA15MW
# Turbine 5, T5: kTI_02, IEA15MW
# Turbine 6, T6: kTI_02, IEA15MW
# Turbine 7, T7: kTI_02, IEA15MW
# Turbine 8, T8: kTI_02, IEA15MW
# Turbine 9, T9: kTI_02, IEA15MW
# Turbine 10, T10: kTI_02, IEA15MW
# Turbine 11, T11: kTI_02, IEA15MW
# Turbine 12, T12: kTI_02, IEA15MW
# Turbine 13, T13: kTI_02, IEA15MW
# Turbine 14, T14: kTI_02, IEA15MW
# Turbine 15, T15: kTI_02, IEA15MW
# Turbine 16, T16: kTI_02, IEA15MW
# Turbine 17, T17: kTI_02, IEA15MW
# Turbine 18, T18: kTI_02, IEA15MW
# Turbine 19, T19: kTI_02, IEA15MW
# Turbine 20, T20: kTI_02, IEA15MW
# Turbine 21, T21: kTI_02, IEA15MW
# Turbine 22, T22: kTI_02, IEA15MW
# Turbine 23, T23: kTI_02, IEA15MW
# Turbine 24, T24: kTI_02, IEA15MW
# Turbine 25, T25: kTI_02, IEA15MW
# Turbine 26, T26: kTI_02, IEA15MW
# Turbine 27, T27: kTI_02, IEA15MW
# Turbine 28, T28: kTI_02, IEA15MW
# Turbine 29, T29: kTI_02, IEA15MW
# Turbine 30, T30: kTI_02, IEA15MW
# Turbine 31, T31: kTI_02, IEA15MW
# Turbine 32, T32: kTI_02, IEA15MW
# Turbine 33, T33: kTI_02, IEA15MW
# Turbine 34, T34: kTI_02, IEA15MW
# Turbine 35, T35: kTI_02, IEA15MW
# Turbine 36, T36: kTI_02, IEA15MW
# Turbine 37, T37: kTI_02, IEA15MW
# Turbine 38, T38: kTI_02, IEA15MW
# Turbine 39, T39: kTI_02, IEA15MW
# Turbine 40, T40: kTI_02, IEA15MW
# Turbine 41, T41: kTI_02, IEA15MW
# Turbine 42, T42: kTI_02, IEA15MW
# Turbine 43, T43: kTI_02, IEA15MW
# Turbine 44, T44: kTI_02, IEA15MW
# Turbine 45, T45: kTI_02, IEA15MW
# Turbine 46, T46: kTI_02, IEA15MW
# Turbine 47, T47: kTI_02, IEA15MW
# Turbine 48, T48: kTI_02, IEA15MW
# Turbine 49, T49: kTI_02, IEA15MW
# Turbine 50, T50: kTI_02, IEA15MW
# Turbine 51, T51: kTI_02, IEA15MW
# Turbine 52, T52: kTI_02, IEA15MW
# Turbine 53, T53: kTI_02, IEA15MW
# Turbine 54, T54: kTI_02, IEA15MW
# Turbine 55, T55: kTI_02, IEA15MW
# Turbine 56, T56: kTI_02, IEA15MW
# Turbine 57, T57: kTI_02, IEA15MW
# Turbine 58, T58: kTI_02, IEA15MW
# Turbine 59, T59: kTI_02, IEA15MW
# Turbine 60, T60: kTI_02, IEA15MW
# Turbine 61, T61: kTI_02, IEA15MW
# Turbine 62, T62: kTI_02, IEA15MW
# Turbine 63, T63: kTI_02, IEA15MW
# Turbine 64, T64: kTI_02, IEA15MW
# Turbine 65, T65: kTI_02, IEA15MW
# Turbine 66, T66: kTI_02, IEA15MW
# Turbine 67, T67: kTI_02, IEA15MW
# Turbine 68, T68: kTI_02, IEA15MW
# Turbine 69, T69: kTI_02, IEA15MW
# Turbine 70, T70: kTI_02, IEA15MW
# Turbine 71, T71: kTI_02, IEA15MW
# Turbine 72, T72: kTI_02, IEA15MW
# Turbine 73, T73: kTI_02, IEA15MW
# Turbine 74, T74: kTI_02, IEA15MW
# Turbine 75, T75: kTI_02, IEA15MW
# Turbine 76, T76: kTI_02, IEA15MW
# Turbine 77, T77: kTI_02, IEA15MW
# Turbine 78, T78: kTI_02, IEA15MW
# Turbine 79, T79: kTI_02, IEA15MW
# Turbine 80, T80: kTI_02, IEA15MW
# Turbine 81, T81: kTI_02, IEA15MW
# Turbine 82, T82: kTI_02, IEA15MW
# Turbine 83, T83: kTI_02, IEA15MW
# Turbine 84, T84: kTI_02, IEA15MW
# Turbine 85, T85: kTI_02, IEA15MW
# Turbine 86, T86: kTI_02, IEA15MW
# Turbine 87, T87: kTI_02, IEA15MW
# Turbine 88, T88: kTI_02, IEA15MW
# Turbine 89, T89: kTI_02, IEA15MW
# Turbine 90, T90: kTI_02, IEA15MW
# Turbine 91, T91: kTI_02, IEA15MW
# Turbine 92, T92: kTI_02, IEA15MW
# Turbine 93, T93: kTI_02, IEA15MW
# Turbine 94, T94: kTI_02, IEA15MW
# Turbine 95, T95: kTI_02, IEA15MW
# Turbine 96, T96: kTI_02, IEA15MW
# Turbine 97, T97: kTI_02, IEA15MW
# Turbine 98, T98: kTI_02, IEA15MW
# Turbine 99, T99: kTI_02, IEA15MW
# Turbine 100, T100: kTI_02, IEA15MW
# Turbine 101, T101: kTI_02, IEA15MW
# Turbine 102, T102: kTI_02, IEA15MW
# Turbine 103, T103: kTI_02, IEA15MW
# Turbine 104, T104: kTI_02, IEA15MW
# Turbine 105, T105: kTI_02, IEA15MW
# Turbine 106, T106: kTI_02, IEA15MW
# Turbine 107, T107: kTI_02, IEA15MW
# Turbine 108, T108: kTI_02, IEA15MW
# Turbine 109, T109: kTI_02, IEA15MW
# Turbine 110, T110: kTI_02, IEA15MW
# Turbine 111, T111: kTI_02, IEA15MW
# Turbine 112, T112: kTI_02, IEA15MW
# Turbine 113, T113: kTI_02, IEA15MW
# Turbine 114, T114: kTI_02, IEA15MW
# Turbine 115, T115: kTI_02, IEA15MW
# Turbine 116, T116: kTI_02, IEA15MW
# Turbine 117, T117: kTI_02, IEA15MW
# Turbine 118, T118: kTI_02, IEA15MW
# Turbine 119, T119: kTI_02, IEA15MW
# Turbine 120, T120: kTI_02, IEA15MW
# Turbine 121, T121: kTI_02, IEA15MW
# Turbine 122, T122: kTI_02, IEA15MW
# Turbine 123, T123: kTI_02, IEA15MW
# Turbine 124, T124: kTI_02, IEA15MW
# Turbine 125, T125: kTI_02, IEA15MW
# Turbine 126, T126: kTI_02, IEA15MW
# Turbine 127, T127: kTI_02, IEA15MW
# Turbine 128, T128: kTI_02, IEA15MW
# Turbine 129, T129: kTI_02, IEA15MW
# Turbine 130, T130: kTI_02, IEA15MW
# Turbine 131, T131: kTI_02, IEA15MW
# Turbine 132, T132: kTI_02, IEA15MW
# [########################################] | 100% Completed | 123.93 ms
# [########################################] | 100% Completed | 276.00 s
# Efficiency added to farm results
# Farm power        : 927.2 MW
# Farm ambient power: 1229.1 MW
# Farm efficiency   : 75.44 %
# Annual farm yield : 8122.13 GWh
# Turbine 0, T0: kTI_02, IEA15MW
# Turbine 1, T1: kTI_02, IEA15MW
# Turbine 2, T2: kTI_02, IEA15MW
# Turbine 3, T3: kTI_02, IEA15MW
# Turbine 4, T4: kTI_02, IEA15MW
# Turbine 5, T5: kTI_02, IEA15MW
# Turbine 6, T6: kTI_02, IEA15MW
# Turbine 7, T7: kTI_02, IEA15MW
# Turbine 8, T8: kTI_02, IEA15MW
# Turbine 9, T9: kTI_02, IEA15MW
# Turbine 10, T10: kTI_02, IEA15MW
# Turbine 11, T11: kTI_02, IEA15MW
# Turbine 12, T12: kTI_02, IEA15MW
# Turbine 13, T13: kTI_02, IEA15MW
# Turbine 14, T14: kTI_02, IEA15MW
# Turbine 15, T15: kTI_02, IEA15MW
# Turbine 16, T16: kTI_02, IEA15MW
# Turbine 17, T17: kTI_02, IEA15MW
# Turbine 18, T18: kTI_02, IEA15MW
# Turbine 19, T19: kTI_02, IEA15MW
# Turbine 20, T20: kTI_02, IEA15MW
# Turbine 21, T21: kTI_02, IEA15MW
# Turbine 22, T22: kTI_02, IEA15MW
# Turbine 23, T23: kTI_02, IEA15MW
# Turbine 24, T24: kTI_02, IEA15MW
# Turbine 25, T25: kTI_02, IEA15MW
# Turbine 26, T26: kTI_02, IEA15MW
# Turbine 27, T27: kTI_02, IEA15MW
# Turbine 28, T28: kTI_02, IEA15MW
# Turbine 29, T29: kTI_02, IEA15MW
# Turbine 30, T30: kTI_02, IEA15MW
# Turbine 31, T31: kTI_02, IEA15MW
# Turbine 32, T32: kTI_02, IEA15MW
# Turbine 33, T33: kTI_02, IEA15MW
# Turbine 34, T34: kTI_02, IEA15MW
# Turbine 35, T35: kTI_02, IEA15MW
# Turbine 36, T36: kTI_02, IEA15MW
# Turbine 37, T37: kTI_02, IEA15MW
# Turbine 38, T38: kTI_02, IEA15MW
# Turbine 39, T39: kTI_02, IEA15MW
# Turbine 40, T40: kTI_02, IEA15MW
# Turbine 41, T41: kTI_02, IEA15MW
# Turbine 42, T42: kTI_02, IEA15MW
# Turbine 43, T43: kTI_02, IEA15MW
# Turbine 44, T44: kTI_02, IEA15MW
# Turbine 45, T45: kTI_02, IEA15MW
# Turbine 46, T46: kTI_02, IEA15MW
# Turbine 47, T47: kTI_02, IEA15MW
# Turbine 48, T48: kTI_02, IEA15MW
# Turbine 49, T49: kTI_02, IEA15MW
# Turbine 50, T50: kTI_02, IEA15MW
# Turbine 51, T51: kTI_02, IEA15MW
# Turbine 52, T52: kTI_02, IEA15MW
# Turbine 53, T53: kTI_02, IEA15MW
# Turbine 54, T54: kTI_02, IEA15MW
# Turbine 55, T55: kTI_02, IEA15MW
# Turbine 56, T56: kTI_02, IEA15MW
# Turbine 57, T57: kTI_02, IEA15MW
# Turbine 58, T58: kTI_02, IEA15MW
# Turbine 59, T59: kTI_02, IEA15MW
# Turbine 60, T60: kTI_02, IEA15MW
# Turbine 61, T61: kTI_02, IEA15MW
# Turbine 62, T62: kTI_02, IEA15MW
# Turbine 63, T63: kTI_02, IEA15MW
# Turbine 64, T64: kTI_02, IEA15MW
# Turbine 65, T65: kTI_02, IEA15MW
# Turbine 66, T66: kTI_02, IEA15MW
# Turbine 67, T67: kTI_02, IEA15MW
# Turbine 68, T68: kTI_02, IEA15MW
# Turbine 69, T69: kTI_02, IEA15MW
# Turbine 70, T70: kTI_02, IEA15MW
# Turbine 71, T71: kTI_02, IEA15MW
# Turbine 72, T72: kTI_02, IEA15MW
# Turbine 73, T73: kTI_02, IEA15MW
# Turbine 74, T74: kTI_02, IEA15MW
# Turbine 75, T75: kTI_02, IEA15MW
# Turbine 76, T76: kTI_02, IEA15MW
# Turbine 77, T77: kTI_02, IEA15MW
# Turbine 78, T78: kTI_02, IEA15MW
# Turbine 79, T79: kTI_02, IEA15MW
# Turbine 80, T80: kTI_02, IEA15MW
# Turbine 81, T81: kTI_02, IEA15MW
# Turbine 82, T82: kTI_02, IEA15MW
# Turbine 83, T83: kTI_02, IEA15MW
# Turbine 84, T84: kTI_02, IEA15MW
# Turbine 85, T85: kTI_02, IEA15MW
# Turbine 86, T86: kTI_02, IEA15MW
# Turbine 87, T87: kTI_02, IEA15MW
# Turbine 88, T88: kTI_02, IEA15MW
# Turbine 89, T89: kTI_02, IEA15MW
# Turbine 90, T90: kTI_02, IEA15MW
# Turbine 91, T91: kTI_02, IEA15MW
# Turbine 92, T92: kTI_02, IEA15MW
# Turbine 93, T93: kTI_02, IEA15MW
# Turbine 94, T94: kTI_02, IEA15MW
# Turbine 95, T95: kTI_02, IEA15MW
# Turbine 96, T96: kTI_02, IEA15MW
# Turbine 97, T97: kTI_02, IEA15MW
# Turbine 98, T98: kTI_02, IEA15MW
# Turbine 99, T99: kTI_02, IEA15MW
# Turbine 100, T100: kTI_02, IEA15MW
# Turbine 101, T101: kTI_02, IEA15MW
# Turbine 102, T102: kTI_02, IEA15MW
# Turbine 103, T103: kTI_02, IEA15MW
# Turbine 104, T104: kTI_02, IEA15MW
# Turbine 105, T105: kTI_02, IEA15MW
# Turbine 106, T106: kTI_02, IEA15MW
# Turbine 107, T107: kTI_02, IEA15MW
# Turbine 108, T108: kTI_02, IEA15MW
# Turbine 109, T109: kTI_02, IEA15MW
# Turbine 110, T110: kTI_02, IEA15MW
# Turbine 111, T111: kTI_02, IEA15MW
# Turbine 112, T112: kTI_02, IEA15MW
# Turbine 113, T113: kTI_02, IEA15MW
# Turbine 114, T114: kTI_02, IEA15MW
# Turbine 115, T115: kTI_02, IEA15MW
# Turbine 116, T116: kTI_02, IEA15MW
# Turbine 117, T117: kTI_02, IEA15MW
# Turbine 118, T118: kTI_02, IEA15MW
# Turbine 119, T119: kTI_02, IEA15MW
# Turbine 120, T120: kTI_02, IEA15MW
# Turbine 121, T121: kTI_02, IEA15MW
# Turbine 122, T122: kTI_02, IEA15MW
# Turbine 123, T123: kTI_02, IEA15MW
# Turbine 124, T124: kTI_02, IEA15MW
# Turbine 125, T125: kTI_02, IEA15MW
# Turbine 126, T126: kTI_02, IEA15MW
# Turbine 127, T127: kTI_02, IEA15MW
# Turbine 128, T128: kTI_02, IEA15MW
# Turbine 129, T129: kTI_02, IEA15MW
# Turbine 130, T130: kTI_02, IEA15MW
# Turbine 131, T131: kTI_02, IEA15MW
# Turbine 132, T132: kTI_02, IEA15MW
# [########################################] | 100% Completed | 126.99 ms
# [########################################] | 100% Completed | 364.71 s
# Efficiency added to farm results
# Farm power        : 937.3 MW
# Farm ambient power: 1229.1 MW
# Farm efficiency   : 76.26 %
# Annual farm yield : 8210.98 GWh
# Turbine 0, T0: kTI_02, IEA15MW
# Turbine 1, T1: kTI_02, IEA15MW
# Turbine 2, T2: kTI_02, IEA15MW
# Turbine 3, T3: kTI_02, IEA15MW
# Turbine 4, T4: kTI_02, IEA15MW
# Turbine 5, T5: kTI_02, IEA15MW
# Turbine 6, T6: kTI_02, IEA15MW
# Turbine 7, T7: kTI_02, IEA15MW
# Turbine 8, T8: kTI_02, IEA15MW
# Turbine 9, T9: kTI_02, IEA15MW
# Turbine 10, T10: kTI_02, IEA15MW
# Turbine 11, T11: kTI_02, IEA15MW
# Turbine 12, T12: kTI_02, IEA15MW
# Turbine 13, T13: kTI_02, IEA15MW
# Turbine 14, T14: kTI_02, IEA15MW
# Turbine 15, T15: kTI_02, IEA15MW
# Turbine 16, T16: kTI_02, IEA15MW
# Turbine 17, T17: kTI_02, IEA15MW
# Turbine 18, T18: kTI_02, IEA15MW
# Turbine 19, T19: kTI_02, IEA15MW
# Turbine 20, T20: kTI_02, IEA15MW
# Turbine 21, T21: kTI_02, IEA15MW
# Turbine 22, T22: kTI_02, IEA15MW
# Turbine 23, T23: kTI_02, IEA15MW
# Turbine 24, T24: kTI_02, IEA15MW
# Turbine 25, T25: kTI_02, IEA15MW
# Turbine 26, T26: kTI_02, IEA15MW
# Turbine 27, T27: kTI_02, IEA15MW
# Turbine 28, T28: kTI_02, IEA15MW
# Turbine 29, T29: kTI_02, IEA15MW
# Turbine 30, T30: kTI_02, IEA15MW
# Turbine 31, T31: kTI_02, IEA15MW
# Turbine 32, T32: kTI_02, IEA15MW
# Turbine 33, T33: kTI_02, IEA15MW
# Turbine 34, T34: kTI_02, IEA15MW
# Turbine 35, T35: kTI_02, IEA15MW
# Turbine 36, T36: kTI_02, IEA15MW
# Turbine 37, T37: kTI_02, IEA15MW
# Turbine 38, T38: kTI_02, IEA15MW
# Turbine 39, T39: kTI_02, IEA15MW
# Turbine 40, T40: kTI_02, IEA15MW
# Turbine 41, T41: kTI_02, IEA15MW
# Turbine 42, T42: kTI_02, IEA15MW
# Turbine 43, T43: kTI_02, IEA15MW
# Turbine 44, T44: kTI_02, IEA15MW
# Turbine 45, T45: kTI_02, IEA15MW
# Turbine 46, T46: kTI_02, IEA15MW
# Turbine 47, T47: kTI_02, IEA15MW
# Turbine 48, T48: kTI_02, IEA15MW
# Turbine 49, T49: kTI_02, IEA15MW
# Turbine 50, T50: kTI_02, IEA15MW
# Turbine 51, T51: kTI_02, IEA15MW
# Turbine 52, T52: kTI_02, IEA15MW
# Turbine 53, T53: kTI_02, IEA15MW
# Turbine 54, T54: kTI_02, IEA15MW
# Turbine 55, T55: kTI_02, IEA15MW
# Turbine 56, T56: kTI_02, IEA15MW
# Turbine 57, T57: kTI_02, IEA15MW
# Turbine 58, T58: kTI_02, IEA15MW
# Turbine 59, T59: kTI_02, IEA15MW
# Turbine 60, T60: kTI_02, IEA15MW
# Turbine 61, T61: kTI_02, IEA15MW
# Turbine 62, T62: kTI_02, IEA15MW
# Turbine 63, T63: kTI_02, IEA15MW
# Turbine 64, T64: kTI_02, IEA15MW
# Turbine 65, T65: kTI_02, IEA15MW
# Turbine 66, T66: kTI_02, IEA15MW
# Turbine 67, T67: kTI_02, IEA15MW
# Turbine 68, T68: kTI_02, IEA15MW
# Turbine 69, T69: kTI_02, IEA15MW
# Turbine 70, T70: kTI_02, IEA15MW
# Turbine 71, T71: kTI_02, IEA15MW
# Turbine 72, T72: kTI_02, IEA15MW
# Turbine 73, T73: kTI_02, IEA15MW
# Turbine 74, T74: kTI_02, IEA15MW
# Turbine 75, T75: kTI_02, IEA15MW
# Turbine 76, T76: kTI_02, IEA15MW
# Turbine 77, T77: kTI_02, IEA15MW
# Turbine 78, T78: kTI_02, IEA15MW
# Turbine 79, T79: kTI_02, IEA15MW
# Turbine 80, T80: kTI_02, IEA15MW
# Turbine 81, T81: kTI_02, IEA15MW
# Turbine 82, T82: kTI_02, IEA15MW
# Turbine 83, T83: kTI_02, IEA15MW
# Turbine 84, T84: kTI_02, IEA15MW
# Turbine 85, T85: kTI_02, IEA15MW
# Turbine 86, T86: kTI_02, IEA15MW
# Turbine 87, T87: kTI_02, IEA15MW
# Turbine 88, T88: kTI_02, IEA15MW
# Turbine 89, T89: kTI_02, IEA15MW
# Turbine 90, T90: kTI_02, IEA15MW
# Turbine 91, T91: kTI_02, IEA15MW
# Turbine 92, T92: kTI_02, IEA15MW
# Turbine 93, T93: kTI_02, IEA15MW
# Turbine 94, T94: kTI_02, IEA15MW
# Turbine 95, T95: kTI_02, IEA15MW
# Turbine 96, T96: kTI_02, IEA15MW
# Turbine 97, T97: kTI_02, IEA15MW
# Turbine 98, T98: kTI_02, IEA15MW
# Turbine 99, T99: kTI_02, IEA15MW
# [########################################] | 100% Completed | 138.73 ms
# [########################################] | 100% Completed | 225.11 s
# Efficiency added to farm results
# Farm power        : 711.9 MW
# Farm ambient power: 924.1 MW
# Farm efficiency   : 77.04 %
# Annual farm yield : 6236.37 GWh

# %%
####-----------------------------------------Results-------------------------------------------#####
# Note: Farm_Results is a list of dataframes

# combine df to single df
Result = Farm_Results[0]
Result.loc[Farm_Results[1].index[0]] = Farm_Results[1].values.flatten().tolist()
Result.loc[Farm_Results[2].index[0]] = Farm_Results[2].values.flatten().tolist()

# calculate Sum for Power and Mean for Efficiency
Result.loc["Sum / Mean"] = [
    Result[Result.columns[0]].sum(),
    Result[Result.columns[1]].sum(),
    Result[Result.columns[2]].mean(),
    Result[Result.columns[3]].sum()
    ]
print(Result)
# Out:
#             Farm power [MW]  Farm ambient power [MW]  Farm efficiency [%]  \
# N-9.1.           927.183839              1229.062639            75.438290
# N-9.2.           937.326025              1229.062639            76.263487
# N-9.3.           711.914366               924.107247            77.038068
# Sum / Mean      2576.424230              3382.232525            76.246615
#
#             Annual farm yield [GWh]
# N-9.1.                  8122.130427
# N-9.2.                  8210.975979
# N-9.3.                  6236.369847
# Sum / Mean             22569.476253

# %% [markdown]
# ### Task 7

# %%
# chose diffrent Parameters
mbook_show = foxes.ModelBook()
mbook_show.print_toc()     # print all available Models
# Out:
# axial_induction
# ---------------
# Betz: BetzAxialInduction()
# Madsen: MadsenAxialInduction()
#
# farm_controllers
# ----------------
# basic_ctrl: BasicFarmController()
#
# farm_models
# -----------
# farm_PMask: Turbine2FarmModel(PowerMask(var_ws_P=REWS3, P_lim=100, induction=Betz))
# farm_hubh_data: Turbine2FarmModel(RotorCentreCalc())
# farm_kTI: Turbine2FarmModel(kTI(kTI=None, kb=0, ti_var=TI, k_var=k))
# farm_kTI_amb: Turbine2FarmModel(kTI(kTI=None, kb=0, ti_var=AMB_TI, k_var=k))
# farm_thrust2ct: Turbine2FarmModel(Thrust2Ct(thrust_var=T, var_ws_ct=REWS2))
# farm_yaw2yawm: Turbine2FarmModel(YAW2YAWM())
# farm_yawm2yaw: Turbine2FarmModel(YAWM2YAW())
#
# partial_wakes
# -------------
# centre: PartialCentre()
# rotor_points: RotorPoints()
# top_hat: PartialTopHat()
#
# axiwake<n>: PartialAxiwake with
#   n=(Number of evaluation points)
#
# grid<n2>: PartialGrid with
#   n2=(Number of points in square grid)
#
# point_models
# ------------
# tke2ti: TKE2TI()
#
# rotor_models
# ------------
# centre: CentreRotor()
#
# grid<n2>: GridRotor with
#   calc_vars=['REWS', 'REWS2', 'REWS3', 'TI', 'RHO']
#   reduce=True
#   n2=(Number of points in square grid)
#
# grid<n2>_raw: GridRotor with
#   calc_vars=['REWS', 'REWS2', 'REWS3', 'TI', 'RHO']
#   reduce=False
#   n2=(Number of points in square grid)
#
# level<n>: LevelRotor with
#   calc_vars=['REWS', 'REWS2', 'REWS3', 'TI', 'RHO']
#   reduce=True
#   n=(Number of vertical levels)
#
# level<n>_raw: LevelRotor with
#   calc_vars=['REWS', 'REWS2', 'REWS3', 'TI', 'RHO']
#   reduce=False
#   n=(Number of vertical levels)
#
# turbine_models
# --------------
# PMask: PowerMask(var_ws_P=REWS3, P_lim=100, induction=Betz)
# hubh_data: RotorCentreCalc()
# kTI: kTI(kTI=None, kb=0, ti_var=TI, k_var=k)
# kTI_amb: kTI(kTI=None, kb=0, ti_var=AMB_TI, k_var=k)
# thrust2ct: Thrust2Ct(thrust_var=T, var_ws_ct=REWS2)
# yaw2yawm: YAW2YAWM()
# yawm2yaw: YAWM2YAW()
#
# kTI_<kTI>_<kb>: kTI with
#   kTI=(Value, e.g. 004 for 0.04)
#   kb=(Value, e.g. 004 for 0.04)
#
# kTI_<kTI>: kTI with
#   kTI=(Value, e.g. 004 for 0.04)
#
# kTI_amb_<kTI>_<kb>: kTI with
#   ti_var=AMB_TI
#   kTI=(Value, e.g. 004 for 0.04)
#   kb=(Value, e.g. 004 for 0.04)
#
# kTI_amb_<kTI>: kTI with
#   ti_var=AMB_TI
#   kTI=(Value, e.g. 004 for 0.04)
#
# turbine_types
# -------------
# DTU10MW: PCtFile(D=178.3, H=119.0, P_nominal=10000.0, P_unit=kW, rho=1.225)
# IEA15MW: PCtFile(D=240.0, H=150.0, P_nominal=15000.0, P_unit=kW, rho=1.225)
# IWT7.5MW: PCtFile(D=164.0, H=100.0, P_nominal=7500.0, P_unit=kW, rho=1.225)
# NREL5MW: PCtFile(D=126.0, H=90.0, P_nominal=5000.0, P_unit=kW, rho=1.225)
# null_type: NullType(D=None, H=None, P_nominal=None, P_unit=kW)
#
# wake_frames
# -----------
# rotor_wd: RotorWD()
# rotor_wd_farmo: FarmOrder()
# timelines: Timelines(dt_min=None)
# yawed: YawedWakes(k_var=k)
#
# yawed_k<k>: YawedWakes with
#   k=(Value, e.g. 004 for 0.04)
#
# streamlines_<step>: Streamlines2D with
#   step=(Step size in m)
#
# streamlines_<step>: Streamlines2D with
#   step=(Step size in m)
#
# timelines_<dt>: Timelines with
#   dt=(Time step, e.g '10s', '1min' etc.)
#
# seq_dyn_wakes_<dt>: SeqDynamicWakes with
#   dt=(Time step, e.g '10s', '1min' etc.)
#
# wake_models
# -----------
# RHB: RankineHalfBody(induction=Madsen)
# Rathmann: Rathmann(induction=Madsen)
# SelfSimilar: SelfSimilar(gamma=1.1, induction=Madsen)
# SelfSimilar2020: SelfSimilar2020(gamma=1.1, induction=Madsen)
#
# Jensen_<superposition>_k<k>: JensenWake with
#   superposition=(Superposition, e.g. linear for ws_linear)
#   k=(Value, e.g. 004 for 0.04)
#
# Jensen_<superposition>: JensenWake with
#   superposition=(Superposition, e.g. linear for ws_linear)
#
# Bastankhah2014_<superposition>_k<k>: Bastankhah2014 with
#   sbeta_factor=0.2
#   superposition=(Superposition, e.g. linear for ws_linear)
#   k=(Value, e.g. 004 for 0.04)
#
# Bastankhah2014_<superposition>: Bastankhah2014 with
#   sbeta_factor=0.2
#   superposition=(Superposition, e.g. linear for ws_linear)
#
# Bastankhah2014B_<superposition>_k<k>: Bastankhah2014 with
#   sbeta_factor=0.2
#   induction=Betz
#   superposition=(Superposition, e.g. linear for ws_linear)
#   k=(Value, e.g. 004 for 0.04)
#
# Bastankhah2014B_<superposition>: Bastankhah2014 with
#   sbeta_factor=0.2
#   induction=Betz
#   superposition=(Superposition, e.g. linear for ws_linear)
#
# Bastankhah025_<superposition>_k<k>: Bastankhah2014 with
#   sbeta_factor=0.25
#   superposition=(Superposition, e.g. linear for ws_linear)
#   k=(Value, e.g. 004 for 0.04)
#
# Bastankhah025_<superposition>: Bastankhah2014 with
#   sbeta_factor=0.25
#   superposition=(Superposition, e.g. linear for ws_linear)
#
# Bastankhah025B_<superposition>_k<k>: Bastankhah2014 with
#   sbeta_factor=0.25
#   induction=Betz
#   superposition=(Superposition, e.g. linear for ws_linear)
#   k=(Value, e.g. 004 for 0.04)
#
# Bastankhah025B_<superposition>: Bastankhah2014 with
#   sbeta_factor=0.25
#   induction=Betz
#   superposition=(Superposition, e.g. linear for ws_linear)
#
# Bastankhah2016_<superposition>_k<k>: Bastankhah2016 with
#   superposition=(Superposition, e.g. linear for ws_linear)
#   k=(Value, e.g. 004 for 0.04)
#
# Bastankhah2016_<superposition>: Bastankhah2016 with
#   superposition=(Superposition, e.g. linear for ws_linear)
#
# Bastankhah2016B_<superposition>_k<k>: Bastankhah2016 with
#   induction=Betz
#   superposition=(Superposition, e.g. linear for ws_linear)
#   k=(Value, e.g. 004 for 0.04)
#
# Bastankhah2016B_<superposition>: Bastankhah2016 with
#   induction=Betz
#   superposition=(Superposition, e.g. linear for ws_linear)
#
# TurbOPark_<superposition>_k<k>: TurbOParkWake with
#   superposition=(Superposition, e.g. linear for ws_linear)
#   k=(Value, e.g. 004 for 0.04)
#
# TurbOPark_<superposition>: TurbOParkWake with
#   superposition=(Superposition, e.g. linear for ws_linear)
#
# TurbOParkB_<superposition>_k<k>: TurbOParkWake with
#   induction=Betz
#   superposition=(Superposition, e.g. linear for ws_linear)
#   k=(Value, e.g. 004 for 0.04)
#
# TurbOParkB_<superposition>: TurbOParkWake with
#   induction=Betz
#   superposition=(Superposition, e.g. linear for ws_linear)
#
# TurbOParkIX_<superposition>_k<k>_dx<dx>: TurbOParkWakeIX with
#   superposition=(Superposition, e.g. linear for ws_linear)
#   k=(Value, e.g. 004 for 0.04)
#   dx=(Integration step in m)
#
# TurbOParkIX_<superposition>_dx<dx>: TurbOParkWakeIX with
#   superposition=(Superposition, e.g. linear for ws_linear)
#   dx=(Integration step in m)
#
# CrespoHernandez_<superposition>_k<k>: CrespoHernandezTIWake with
#   use_ambti=False
#   superposition=(Superposition, e.g. linear for ti_linear)
#   k=(Value, e.g. 004 for 0.04)
#
# CrespoHernandez_<superposition>: CrespoHernandezTIWake with
#   use_ambti=False
#   superposition=(Superposition, e.g. linear for ti_linear)
#
# IECTI2005_<superposition>: IECTIWake with
#   iec_type=2005
#   superposition=(Superposition, e.g. linear for ti_linear)
#
# IECTI2019_<superposition>: IECTIWake with
#   iec_type=2019
#   superposition=(Superposition, e.g. linear for ti_linear)
#
# wake_superpositions
# -------------------
# ti_cubic: TIPow(pow=3, superp_to_amb=quadratic)
# ti_linear: TILinear(superp_to_amb=quadratic)
# ti_max: TIMax(superp_to_amb=quadratic)
# ti_quadratic: TIQuadratic(superp_to_amb=quadratic)
# ti_quartic: TIPow(pow=4, superp_to_amb=quadratic)
# ws_cubic: WSPow(pow=3, scale_amb=False, lim_low=None, lim_high=None)
# ws_cubic_amb: WSPow(pow=3, scale_amb=True, lim_low=None, lim_high=None)
# ws_cubic_loc: WSPowLocal(pow=3, lim_low=None, lim_high=None)
# ws_cubic_loc_lim: WSPowLocal(pow=3, lim_low=0.0001, lim_high=None)
# ws_linear: WSLinear(scale_amb=False, lim_low=None, lim_high=None)
# ws_linear_amb: WSLinear(scale_amb=True, lim_low=None, lim_high=None)
# ws_linear_amb_lim: WSLinear(scale_amb=True, lim_low=0.0001, lim_high=None)
# ws_linear_lim: WSLinear(scale_amb=False, lim_low=0.0001, lim_high=None)
# ws_linear_loc: WSLinearLocal(lim_low=None, lim_high=None)
# ws_linear_loc_lim: WSLinearLocal(lim_low=0.0001, lim_high=None)
# ws_max: WSMax(scale_amb=False, lim_low=None, lim_high=None)
# ws_max_amb: WSMax(scale_amb=True, lim_low=None, lim_high=None)
# ws_max_loc: WSMaxLocal(lim_low=None, lim_high=None)
# ws_max_loc_lim: WSMaxLocal(lim_low=0.0001, lim_high=None)
# ws_product: WSProduct(lim_low=None, lim_high=None)
# ws_product_lim: WSProduct(lim_low=0.0001, lim_high=None)
# ws_quadratic: WSQuadratic(scale_amb=False, lim_low=None, lim_high=None)
# ws_quadratic_amb: WSQuadratic(scale_amb=True, lim_low=None, lim_high=None)
# ws_quadratic_amb_lim: WSQuadratic(scale_amb=True, lim_low=0.0001, lim_high=None)
# ws_quadratic_lim: WSQuadratic(scale_amb=False, lim_low=0.0001, lim_high=None)
# ws_quadratic_loc: WSQuadraticLocal(lim_low=None, lim_high=None)
# ws_quadratic_loc_lim: WSQuadraticLocal(lim_low=0.0001, lim_high=None)
# ws_quartic: WSPow(pow=4, scale_amb=False, lim_low=None, lim_high=None)
# ws_quartic_amb: WSPow(pow=4, scale_amb=True, lim_low=None, lim_high=None)
# ws_quartic_loc: WSPowLocal(pow=4, lim_low=None, lim_high=None)
# ws_quartic_loc_lim: WSPowLocal(pow=4, lim_low=0.0001, lim_high=None)

# %%
# ###--------------------------------------Important Parameters---------------------------------------###
# Parameters = dict(
#     TType         = "IEA15MW",                  #"NREL5MW","IEA15MW"
#     rotor_model   = "centre",
#     wake_models   = ["Bastankhah2014_linear"],
#     partial_wakes = None,
#     )

# ###--------------------------------------compute farm results--------------------------------------###
# Farm_Results = []
# for Farm in Turb_dfs:
#     Farm_Results.append(Foxes_Farm_Power(Farm,States,Parameters))
